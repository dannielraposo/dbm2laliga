# %% [markdown]
# # 0. Importing libraries

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import fpgrowth

# %% [markdown]
# # 1. Frequent Pattern Mining

# %%
playersFPM = pd.read_csv(r'datacsv/playerFPM.csv')
playersFPM.head()
# Out:
#    gamesplayedavg  goalscoredbin  goalswhilepitchavg  interceptionsavg  \
# 0           False          False               False             False
# 1           False          False               False             False
# 2            True          False                True             False
# 3           False          False               False             False
# 4           False          False               False              True
#
#    recoveriesavg  clearancesavg  offsidesbin  foulssufferedavg  \
# 0          False          False        False             False
# 1          False          False        False             False
# 2           True          False        False             False
# 3           True          False        False             False
# 4           True           True        False             False
#
#    foulscommittedavg  penaltieswonbin  penaltiesgivenbin  handballsbin  \
# 0              False            False              False         False
# 1              False            False              False         False
# 2              False            False              False         False
# 3              False            False               True         False
# 4              False            False              False          True
#
#    shotsavg  assistsbin  cornersbin  duelsavg  offensivebin  deffensivebin
# 0     False       False       False     False         False           True
# 1     False       False       False     False         False           True
# 2     False        True       False     False         False           True
# 3     False       False       False     False         False           True
# 4     False       False       False     False         False           True

# %%
apriori(playersFPM, min_support=0.35, use_colnames=True)
# Out:
#      support                                           itemsets
# 0   0.543986                                   (gamesplayedavg)
# 1   0.463196                                    (goalscoredbin)
# 2   0.463196                               (goalswhilepitchavg)
# 3   0.377020                                 (interceptionsavg)
# 4   0.764811                                    (recoveriesavg)
# 5   0.493716                                      (offsidesbin)
# 6   0.369838                                 (foulssufferedavg)
# 7   0.423698                                (foulscommittedavg)
# 8   0.454219                                     (handballsbin)
# 9   0.432675                                       (assistsbin)
# 10  0.464991                                         (duelsavg)
# 11  0.707361                                    (deffensivebin)
# 12  0.396768                    (gamesplayedavg, goalscoredbin)
# 13  0.443447               (gamesplayedavg, goalswhilepitchavg)
# 14  0.543986                    (gamesplayedavg, recoveriesavg)
# 15  0.396768                      (gamesplayedavg, offsidesbin)
# 16  0.402154                (gamesplayedavg, foulscommittedavg)
# 17  0.371634                     (gamesplayedavg, handballsbin)
# 18  0.362657                       (gamesplayedavg, assistsbin)
# 19  0.445242                         (gamesplayedavg, duelsavg)
# 20  0.377020                    (gamesplayedavg, deffensivebin)
# 21  0.447038                     (goalscoredbin, recoveriesavg)
# 22  0.378815                       (goalscoredbin, offsidesbin)
# 23  0.362657                          (goalscoredbin, duelsavg)
# 24  0.463196                (goalswhilepitchavg, recoveriesavg)
# 25  0.393178                     (duelsavg, goalswhilepitchavg)
# 26  0.377020                  (interceptionsavg, recoveriesavg)
# 27  0.470377                       (offsidesbin, recoveriesavg)
# 28  0.368043                  (foulssufferedavg, recoveriesavg)
# 29  0.423698                 (foulscommittedavg, recoveriesavg)
# 30  0.432675                      (handballsbin, recoveriesavg)
# 31  0.420108                        (assistsbin, recoveriesavg)
# 32  0.463196                          (duelsavg, recoveriesavg)
# 33  0.536804                     (recoveriesavg, deffensivebin)
# 34  0.364452                            (offsidesbin, duelsavg)
# 35  0.398564                      (duelsavg, foulscommittedavg)
# 36  0.396768     (gamesplayedavg, goalscoredbin, recoveriesavg)
# 37  0.351885          (gamesplayedavg, goalscoredbin, duelsavg)
# 38  0.443447  (gamesplayedavg, goalswhilepitchavg, recoverie...
# 39  0.385996     (gamesplayedavg, duelsavg, goalswhilepitchavg)
# 40  0.396768       (gamesplayedavg, offsidesbin, recoveriesavg)
# 41  0.402154  (gamesplayedavg, foulscommittedavg, recoveries...
# 42  0.371634      (gamesplayedavg, handballsbin, recoveriesavg)
# 43  0.362657        (gamesplayedavg, assistsbin, recoveriesavg)
# 44  0.445242          (gamesplayedavg, duelsavg, recoveriesavg)
# 45  0.377020     (gamesplayedavg, recoveriesavg, deffensivebin)
# 46  0.350090            (gamesplayedavg, offsidesbin, duelsavg)
# 47  0.385996      (gamesplayedavg, duelsavg, foulscommittedavg)
# 48  0.369838        (goalscoredbin, offsidesbin, recoveriesavg)
# 49  0.360862           (goalscoredbin, duelsavg, recoveriesavg)
# 50  0.393178      (duelsavg, goalswhilepitchavg, recoveriesavg)
# 51  0.362657             (offsidesbin, duelsavg, recoveriesavg)
# 52  0.398564       (duelsavg, foulscommittedavg, recoveriesavg)
# 53  0.351885  (gamesplayedavg, goalscoredbin, duelsavg, reco...
# 54  0.385996  (gamesplayedavg, duelsavg, goalswhilepitchavg,...
# 55  0.350090  (gamesplayedavg, offsidesbin, duelsavg, recove...
# 56  0.385996  (gamesplayedavg, duelsavg, foulscommittedavg, ...

# %%
fpgrowth(playersFPM, min_support=0.35, use_colnames=True)[0:30]
# Out:
#      support                                           itemsets
# 0   0.707361                                    (deffensivebin)
# 1   0.764811                                    (recoveriesavg)
# 2   0.543986                                   (gamesplayedavg)
# 3   0.463196                               (goalswhilepitchavg)
# 4   0.432675                                       (assistsbin)
# 5   0.454219                                     (handballsbin)
# 6   0.377020                                 (interceptionsavg)
# 7   0.464991                                         (duelsavg)
# 8   0.423698                                (foulscommittedavg)
# 9   0.369838                                 (foulssufferedavg)
# 10  0.493716                                      (offsidesbin)
# 11  0.463196                                    (goalscoredbin)
# 12  0.536804                     (recoveriesavg, deffensivebin)
# 13  0.543986                    (gamesplayedavg, recoveriesavg)
# 14  0.377020                    (gamesplayedavg, deffensivebin)
# 15  0.377020     (gamesplayedavg, recoveriesavg, deffensivebin)
# 16  0.463196                (goalswhilepitchavg, recoveriesavg)
# 17  0.443447               (gamesplayedavg, goalswhilepitchavg)
# 18  0.393178                     (duelsavg, goalswhilepitchavg)
# 19  0.443447  (gamesplayedavg, goalswhilepitchavg, recoverie...
# 20  0.393178      (duelsavg, goalswhilepitchavg, recoveriesavg)
# 21  0.385996     (gamesplayedavg, duelsavg, goalswhilepitchavg)
# 22  0.385996  (gamesplayedavg, duelsavg, goalswhilepitchavg,...
# 23  0.420108                        (assistsbin, recoveriesavg)
# 24  0.362657                       (gamesplayedavg, assistsbin)
# 25  0.362657        (gamesplayedavg, assistsbin, recoveriesavg)
# 26  0.432675                      (handballsbin, recoveriesavg)
# 27  0.371634                     (gamesplayedavg, handballsbin)
# 28  0.371634      (gamesplayedavg, handballsbin, recoveriesavg)
# 29  0.377020                  (interceptionsavg, recoveriesavg)
